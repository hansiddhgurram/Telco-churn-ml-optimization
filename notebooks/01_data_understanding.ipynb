# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams["figure.figsize"] = (8, 5)
sns.set_style("whitegrid")

# %%
df = pd.read_csv("../data/raw/Telco-Customer-Churn.csv")
df.head()

# %%
print("Shape of dataset:", df.shape)
df.info()

# %%
df.describe()

# %%
df['Churn'].value_counts()
df['Churn'].value_counts(normalize=True)
sns.countplot(x='Churn', data=df)
plt.title('Churn Distribution')
plt.show()

# %%
df.isnull().sum()

# %%
df['TotalCharges'].head(10)
df['TotalCharges'].dtype

# %%
categorical_cols = df.select_dtypes(include='object').columns
categorical_cols

# %%
sns.countplot(x='Contract', hue='Churn', data=df)
plt.xticks(rotation=30)
plt.title("Churn by Contract Type")
plt.show()

# %%
sns.countplot(x='InternetService', hue='Churn', data=df)
plt.title("Churn by Internet Service")
plt.show()

# %%
sns.countplot(x='PaymentMethod', hue='Churn', data=df)
plt.xticks(rotation=45)
plt.title("Churn by Payment Method")
plt.show()

# %%
sns.histplot(df['tenure'], kde=True)
plt.title("Tenure Distribution")
plt.show()
sns.boxplot(x='Churn', y='tenure', data=df)
plt.title("Tenure vs Churn")
plt.show()

# %%
sns.histplot(df['MonthlyCharges'], kde=True)
plt.title("Monthly Charges Distribution")
plt.show()
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title("Monthly Charges vs Churn")
plt.show()

# %%
sns.countplot(x='SeniorCitizen', hue='Churn', data=df)
plt.title("Senior Citizen vs Churn")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])

corr = numeric_df.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Dataset contains both categorical and numerical features
# Target variable Churn is imbalanced
# TotalCharges needs type conversion and cleaning
# Month-to-month contracts show higher churn
# Customers with low tenure are more likely to churn
# Multiple categorical features need encoding
#
# Baseline model will struggle without preprocessing
# Feature scaling and encoding are required
# Class imbalance must be handled
# Better models and tuning can significantly improve results
